# %%
import pandas as pd

# %%
import numpy as np

# %%
data=pd.read_csv("IPL 2022.csv")
data
# Out:
#     match_id           date                                         venue  \
# 0          1  March 26,2022                      Wankhede Stadium, Mumbai
# 1          2  March 27,2022                     Brabourne Stadium, Mumbai
# 2          3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3          4  March 28,2022                      Wankhede Stadium, Mumbai
# 4          5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
# ..       ...            ...                                           ...
# 69        70    May 22,2022                      Wankhede Stadium, Mumbai
# 70        71    May 24,2022                         Eden Gardens, Kolkata
# 71        72    May 25,2022                         Eden Gardens, Kolkata
# 72        73    May 27,2022              Narendra Modi Stadium, Ahmedabad
# 73        74    May 29,2022              Narendra Modi Stadium, Ahmedabad
#
#         team1      team2    stage toss_winner toss_decision  first_ings_score  \
# ...

# %%
data.to_excel('ipl2022.xlsx')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 data.to_excel('ipl2022.xlsx')
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py:2417, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
# ...

# %%
data.head(10)
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
# 5         6  March 30,2022            Dr DY Patil Sports Academy, Mumbai
# 6         7  March 31,2022                     Brabourne Stadium, Mumbai
# 7         8   April 1,2022                      Wankhede Stadium, Mumbai
# 8         9   April 2,2022            Dr DY Patil Sports Academy, Mumbai
# 9        10   April 2,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   match_id             74 non-null     int64
#  1   date                 74 non-null     object
#  2   venue                74 non-null     object
#  3   team1                74 non-null     object
#  4   team2                74 non-null     object
#  5   stage                74 non-null     object
#  6   toss_winner          74 non-null     object
#  7   toss_decision        74 non-null     object
#  8   first_ings_score     74 non-null     int64
#  9   first_ings_wkts      74 non-null     int64
#  10  second_ings_score    74 non-null     int64
#  11  second_ings_wkts     74 non-null     int64
#  12  match_winner         74 non-null     object
#  13  won_by               74 non-null     object
#  14  margin               74 non-null     int64
# ...

# %%
data.shape
# Out:
# (74, 20)

# %%
data.columns
# Out:
# Index(['match_id', 'date', 'venue', 'team1', 'team2', 'stage', 'toss_winner',
#        'toss_decision', 'first_ings_score', 'first_ings_wkts',
#        'second_ings_score', 'second_ings_wkts', 'match_winner', 'won_by',
#        'margin', 'player_of_the_match', 'top_scorer', 'highscore',
#        'best_bowling', 'best_bowling_figure'],
#       dtype='object')

# %%
l=['team1','team2']
data[l]
# Out:
#         team1      team2
# 0     Chennai    Kolkata
# 1       Delhi     Mumbai
# 2    Banglore     Punjab
# 3     Gujarat    Lucknow
# 4   Hyderabad  Rajasthan
# ..        ...        ...
# 69  Hyderabad     Punjab
# 70    Gujarat  Rajasthan
# 71   Banglore    Lucknow
# 72   Banglore  Rajasthan
# 73    Gujarat  Rajasthan
#
# [74 rows x 2 columns]

# %%
df=data.loc[data['match_winner']=='Kolkata']
df
# Out:
#     match_id           date                                         venue  \
# 0          1  March 26,2022                      Wankhede Stadium, Mumbai
# 7          8   April 1,2022                      Wankhede Stadium, Mumbai
# 13        14   April 6,2022  Maharashtra Cricket Association Stadium,Pune
# 46        47     May 2,2022                      Wankhede Stadium, Mumbai
# 55        56     May 9,2022            Dr DY Patil Sports Academy, Mumbai
# 60        61    May 14,2022  Maharashtra Cricket Association Stadium,Pune
#
#         team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0     Chennai    Kolkata  Group     Kolkata         Field               131
# 7     Kolkata     Punjab  Group     Kolkata         Field               137
# 13    Kolkata     Mumbai  Group     Kolkata         Field               161
# 46    Kolkata  Rajasthan  Group     Kolkata         Field               152
# ...

# %%
data['first_ings_score'].mean()
# Out:
# 171.1216216216216

# %%
data['second_ings_score'].max()
# Out:
# 211

# %%
ndf=data.sort_values('first_ings_score',ascending=False)
ndf
# Out:
#     match_id           date                                         venue  \
# 33        34  April 22,2022                      Wankhede Stadium, Mumbai
# 29        30  April 18,2022                     Brabourne Stadium, Mumbai
# 21        22  April 12,2022            Dr DY Patil Sports Academy, Mumbai
# 18        19  April 10,2022                     Brabourne Stadium, Mumbai
# 4          5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
# ..       ...            ...                                           ...
# 73        74    May 29,2022              Narendra Modi Stadium, Ahmedabad
# 5          6  March 30,2022            Dr DY Patil Sports Academy, Mumbai
# 31        32  April 20,2022                     Brabourne Stadium, Mumbai
# 58        59    May 12,2022                      Wankhede Stadium, Mumbai
# 35        36  April 23,2022                     Brabourne Stadium, Mumbai
#
#         team1      team2  stage toss_winner toss_decision  first_ings_score  \
# ...

# %%
data['match_id'].count()
# Out:
# 74

# %%
data['team1'].unique()
# Out:
# array(['Chennai', 'Delhi', 'Banglore', 'Gujarat', 'Hyderabad', 'Kolkata',
#        'Mumbai', 'Lucknow', 'Punjab'], dtype=object)

# %%
data['first_ings_score'].max()
# Out:
# 222

# %%
data.loc[data['first_ings_score']==222]
# Out:
#     match_id           date                     venue  team1      team2  \
# 33        34  April 22,2022  Wankhede Stadium, Mumbai  Delhi  Rajasthan
#
#     stage toss_winner toss_decision  first_ings_score  first_ings_wkts  \
# 33  Group       Delhi         Field               222                2
#
#     second_ings_score  second_ings_wkts match_winner won_by  margin  \
# 33                207                 8    Rajasthan   Runs      15
#
#    player_of_the_match   top_scorer  highscore     best_bowling  \
# 33         Jos Buttler  Jos Buttler        116  Prasidh Krishna
#
#    best_bowling_figure
# 33               3--22

# %%
match_win_count=data['match_winner'].value_counts().reset_index()
match_win_count
# Out:
#   match_winner  count
# 0      Gujarat     12
# 1    Rajasthan     10
# 2     Banglore      9
# 3      Lucknow      9
# 4        Delhi      7
# 5       Punjab      7
# 6      Kolkata      6
# 7    Hyderabad      6
# 8      Chennai      4
# 9       Mumbai      4

# %%
data['score_dif']=data['second_ings_score']-data['first_ings_score']
data
# Out:
#     match_id           date                                         venue  \
# 0          1  March 26,2022                      Wankhede Stadium, Mumbai
# 1          2  March 27,2022                     Brabourne Stadium, Mumbai
# 2          3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3          4  March 28,2022                      Wankhede Stadium, Mumbai
# 4          5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
# ..       ...            ...                                           ...
# 69        70    May 22,2022                      Wankhede Stadium, Mumbai
# 70        71    May 24,2022                         Eden Gardens, Kolkata
# 71        72    May 25,2022                         Eden Gardens, Kolkata
# 72        73    May 27,2022              Narendra Modi Stadium, Ahmedabad
# 73        74    May 29,2022              Narendra Modi Stadium, Ahmedabad
#
#         team1      team2    stage toss_winner toss_decision  first_ings_score  \
# ...

# %%
more_10=data.loc[data['score_dif']>10]
more_10
# Out:
# Empty DataFrame
# Columns: [match_id, date, venue, team1, team2, stage, toss_winner, toss_decision, first_ings_score, first_ings_wkts, second_ings_score, second_ings_wkts, match_winner, won_by, margin, player_of_the_match, top_scorer, highscore, best_bowling, best_bowling_figure, score_dif]
# Index: []
#
# [0 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   match_id             74 non-null     int64
#  1   date                 74 non-null     object
#  2   venue                74 non-null     object
#  3   team1                74 non-null     object
#  4   team2                74 non-null     object
#  5   stage                74 non-null     object
#  6   toss_winner          74 non-null     object
#  7   toss_decision        74 non-null     object
#  8   first_ings_score     74 non-null     int64
#  9   first_ings_wkts      74 non-null     int64
#  10  second_ings_score    74 non-null     int64
#  11  second_ings_wkts     74 non-null     int64
#  12  match_winner         74 non-null     object
#  13  won_by               74 non-null     object
#  14  margin               74 non-null     int64
# ...

# %%
data=data.drop(columns='score_diff')
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 data=data.drop(columns='score_diff')
#       2 data
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
# ...

# %%
10=data.loc[data['score_dif']>=10]
10
# Out:
#   Cell In[84], line 1
#     10=data.loc[data['score_dif']>=10]
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
large_diff = df[df['score_dif'] > 10]
large_diff
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'score_dif'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 large_diff = df[df['score_dif'] > 10]
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   match_id             74 non-null     int64
#  1   date                 74 non-null     object
#  2   venue                74 non-null     object
#  3   team1                74 non-null     object
#  4   team2                74 non-null     object
#  5   stage                74 non-null     object
#  6   toss_winner          74 non-null     object
#  7   toss_decision        74 non-null     object
#  8   first_ings_score     74 non-null     int64
#  9   first_ings_wkts      74 non-null     int64
#  10  second_ings_score    74 non-null     int64
#  11  second_ings_wkts     74 non-null     int64
#  12  match_winner         74 non-null     object
#  13  won_by               74 non-null     object
#  14  margin               74 non-null     int64
# ...

# %%
data['date'] = pd.to_datetime(data['date'], format='%B%d,%Y',coerce='error')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 data['date'] = pd.to_datetime(data['date'], format='%B%d,%Y',coerce='error')
#
# TypeError: to_datetime() got an unexpected keyword argument 'coerce'

# %%
data=data.replace('Kolkata','kolkata knight riders')
data
# Out:
#     match_id           date                                         venue  \
# 0          1  March 26,2022                      Wankhede Stadium, Mumbai
# 1          2  March 27,2022                     Brabourne Stadium, Mumbai
# 2          3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3          4  March 28,2022                      Wankhede Stadium, Mumbai
# 4          5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
# ..       ...            ...                                           ...
# 69        70    May 22,2022                      Wankhede Stadium, Mumbai
# 70        71    May 24,2022                         Eden Gardens, Kolkata
# 71        72    May 25,2022                         Eden Gardens, Kolkata
# 72        73    May 27,2022              Narendra Modi Stadium, Ahmedabad
# 73        74    May 29,2022              Narendra Modi Stadium, Ahmedabad
#
#         team1                  team2    stage            toss_winner  \
# ...

# %%
data['date']=pd.to_datetime(data['date'])
data['date']
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_22920\2911049914.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['date']=pd.to_datetime(data['date'])
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# File conversion.pyx:326, in pandas._libs.tslibs.conversion._TSObject.ensure_reso()
#
# File np_datetime.pyx:683, in pandas._libs.tslibs.np_datetime.convert_reso()
#
# OverflowError: result would overflow
#
# The above exception was the direct cause of the following exception:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 data['date']=pd.to_datetime(data['date'])
#       2 data['date']
#
# ...

# %%
data['first_ings_score'].sum()+data['second_ings_score'].sum()
# Out:
# 24395
